# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import datetime
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests

driver=webdriver.Chrome(r"D:\chromedriver.exe")
# Out:
# <ipython-input-1-a1f309f245b0>:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"D:\chromedriver.exe")

# %% [markdown]
# !activate tf_gpu_env

# %% [markdown]
# pip install --user ipykernel tf_gpu_env

# %% [markdown]
# !pip install tensorflow-gpu==2.0.0

# %% [markdown]
# pip install tensorflow-gpu

# %% [markdown]
# import tensorflow as tf
#
# if tf.test.gpu_device_name():
#     print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# else:
#     print("Please install GPU version of TF")

# %% [markdown]
# tf.version.VERSION

# %% [markdown]
# print(tf.config.list_physical_devices())

# %% [markdown]
# # TRAIN DATA

# %% [markdown]
# # SAREES

# %%
url_saree='https://www.amazon.in/s?k=Sarees+%28women%29&ref=nb_sb_noss_2'
driver.get(url_saree)
time.sleep(2)

# %%
#scrapping images

a=0

for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 100))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\sarees\saree"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-4-519e6782415f>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-4-519e6782415f>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %%
#scrapping images
url_saree='https://www.amazon.in/s?k=Sarees+%28women%29&page=4&qid=1637931397&ref=sr_pg_4'
driver.get(url_saree)
time.sleep(2)
a=3

for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 100))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\sarees\saree"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-17-99de21a40f22>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-17-99de21a40f22>:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %% [markdown]
# # Trousers

# %%
url_Trousers='https://www.amazon.in/s?k=trousers&ref=nb_sb_noss_2'
driver.get(url_Trousers)

time.sleep(2)

#scrapping images
a=0
for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 60))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\Trousers\Trouser"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-5-de6d62e323ad>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-5-de6d62e323ad>:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %%
url_Trousers='https://www.amazon.in/s?k=trousers&page=4&qid=1637931485&ref=sr_pg_4'
driver.get(url_Trousers)

time.sleep(2)

#scrapping images
a=4
for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 60))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\Trousers\Trouser"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-18-fe136da1a2d7>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-18-fe136da1a2d7>:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %% [markdown]
# # JEANS

# %%
url_Jeans='https://www.amazon.in/s?k=Jeans&ref=nb_sb_noss_2'
driver.get(url_Jeans)

# %%
time.sleep(2)

#scrapping images
a=0
for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 70))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\Jeans\jeans"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-7-394e5ea40831>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-7-394e5ea40831>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %%
url_Jeans='https://www.amazon.in/s?k=Jeans&page=4&qid=1637931541&ref=sr_pg_4'
driver.get(url_Jeans)

time.sleep(2)

#scrapping images
a=4
for i in range(0,6): 
            images = driver.find_elements_by_xpath('//img[@class="s-image"]')

            img_urls = []
            img_data = []
            for image in images:
                source= image.get_attribute('src')
                if source is not None:
                    if(source[0:4] == 'http'):
                        img_urls.append(source)
                        
                        
            b=len(img_urls)
            for i in range(b):
                if i >= 1000:
                    break
                print("Downloading {0} of {1} images" .format(i, 70))
                response= requests.get(img_urls[i])
                file = open(r"D:\folders\fliprobo\assignment 13\images\train_images_amazon\Jeans\jeans"+str(a)+str(i)+".jpg", "wb")
                file.write(response.content) 
                time.sleep(2)
                
            try:
                button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
                driver.execute_script("arguments[0].click();", button)
                a+=1
            except NoSuchElementException:
                pass
                time.sleep(2)
# Out:
# <ipython-input-19-4ffcb5689234>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="s-image"]')
# ...
# <ipython-input-19-4ffcb5689234>:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
# ...

# %% [markdown]
# # TEST DATA

# %% [markdown]
# **1.SAREES**

# %%
url_test_sarees='https://www.flipkart.com/womens-sarees/pr?sid=clo%2C8on%2Czpd%2C9og&otracker[]=categorytree&otracker[]=nmenu_sub_Women_0_Sarees'
driver.get(url_test_sarees)

time.sleep(2)
#scrapping images
a=0
images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)


b=len(img_urls)
for i in range(b):
    if i >= 1000:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\folders\fliprobo\assignment 13\images\test_images_flipkart\sarees\saree"+str(a)+str(i)+".jpg", "wb")
    file.write(response.content) 
    time.sleep(2)
# Out:
# <ipython-input-9-2b93422e8fc2>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
# ...

# %%
url_test_Trousers='https://www.flipkart.com/clothing-and-accessories/bottomwear/trouser/men-trouser/pr?sid=clo%2Cvua%2Cmle%2Clhk&otracker=categorytree&p%5B%5D=facets.occasion%255B%255D%3DFormal&otracker=nmenu_sub_Men_0_Formal%20Trousers'
driver.get(url_test_Trousers)

time.sleep(2)

#scrapping images
a=0
images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)


b=len(img_urls)
for i in range(b):
    if i >= 1000:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\folders\fliprobo\assignment 13\images\test_images_flipkart\Trousers\Trouser"+str(a)+str(i)+".jpg", "wb")
    file.write(response.content) 
    time.sleep(2)
# Out:
# <ipython-input-15-464520480ae3>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
# ...

# %%
url_Jeans='https://www.flipkart.com/search?q=jeans&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
driver.get(url_Jeans)

time.sleep(2)

#scrapping images
a=0

images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)


b=len(img_urls)
for i in range(b):
    if i >= 1000:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\folders\fliprobo\assignment 13\images\test_images_flipkart\Jeans\jeans"+str(a)+str(i)+".jpg", "wb")
    file.write(response.content) 
    time.sleep(2)
# Out:
# <ipython-input-16-8d8589240c9c>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
# ...

# %% [markdown]
# Train data consists of images from amazon and test data consists of images from flipkart
